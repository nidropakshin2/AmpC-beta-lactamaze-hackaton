# %%
import pandas as pd

df = pd.read_csv("dataset/data_rdkit_preprocessed.csv")
df.head()
# Out:
#                                               Smiles     pIC50  \
# 0  Br.CC(C)(NCc1cc([N+](=O)[O-])cc2nc(O)c(O)nc12)...  6.537602
# 1  Br.CC(C)OC(=O)CN1Cc2cc(OCCCC(=O)N(C)C3CCCCC3)c...  7.200659
# 2  Br.CC(OC(=O)CN1Cc2cc(OCCCC(=O)N(C)C3CCCCC3)ccc...  6.327902
# 3  Br.CC(OC(=O)CN1Cc2cc(OCCCC(=O)N(C)C3CCCCC3)ccc...  8.096910
# 4    Br.CC1CCCN(Cc2cc3nc(O)c(O)nc3cc2[N+](=O)[O-])C1  6.221849
#
#                                               smiles  activity
# 0  CC(C)(NCc1cc([N+](=O)[O-])cc2nc(O)c(O)nc12)C(=O)O  6.537602
# 1  CC(C)OC(=O)CN1Cc2cc(OCCCC(=O)N(C)C3CCCCC3)ccc2...  7.200659
# 2  CC(OC(=O)CN1Cc2cc(OCCCC(=O)N(C)C3CCCCC3)ccc2N=...  6.327902
# 3  CC(OC(=O)CN1Cc2cc(OCCCC(=O)N(C)C3CCCCC3)ccc2N=...  8.096910
# 4       CC1CCCN(Cc2cc3nc(O)c(O)nc3cc2[N+](=O)[O-])C1  6.221849

# %%
import numpy as np
y = df["activity"].to_numpy()
print(np.percentile(y, [10, 50, 90]))
# Out:
# [4.45593196 6.30103    8.15490196]
